# %% [markdown]
# <a href="https://colab.research.google.com/github/sanaaria/Algorithms-of-data-science/blob/main/Optimization_hyper_parameters_Esol.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import TensorDataset
from pandas import read_csv
from sklearn.impute import SimpleImputer

# %%
from google.colab import files
 
 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d2d82f9b-d233-4320-9f08-942fc24080ef" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d2d82f9b-d233-4320-9f08-942fc24080ef">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Esol.csv to Esol.csv

# %%
import pandas as pd
import io
 
data = pd.read_csv(io.BytesIO(uploaded['Esol.csv']))

# %%
data.isnull().sum().sum()
# Out:
# 0

# %%
Xdata = data.iloc[:,0:200]
Ydata = data.iloc[:,200:201]

# %%
Ydata.shape
# Out:
# (1128, 1)

# %%
Xdata.shape
# Out:
# (1128, 200)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(Xdata, Ydata, test_size=0.3, random_state=1)

# %%
from sklearn import preprocessing

# scaler_data = preprocessing.MinMaxScaler()
# X_train = scaler_data.fit_transform(X_train)
# X_test = scaler_data.transform(X_test)
scaler_labels = preprocessing.MinMaxScaler()
Y_train = scaler_labels.fit_transform(Y_train.values.reshape(-1, 1))
Y_test = scaler_labels.transform(Y_test.values.reshape(-1, 1))

print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape)
#print(X_train)
#print("Train labels before scaling: {} {} {}Train labels after scaling: {} {}".format('\n',train_labels_before,'\n', '\n', train_labels))
# Out:
# (789, 200) (789, 1) (339, 200) (339, 1)

# %%
type(X_train)
# Out:
# pandas.core.frame.DataFrame

# %%
X_train=np.array(X_train)
X_test=np.array(X_test)

# %%
X_train.shape
# Out:
# (789, 200)

# %%
# from sklearn.linear_model import LinearRegression
# from sklearn import metrics
# model= LinearRegression(fit_intercept=False)
# model2=model.fit(X_train, Y_train)
# print(model2.summary())

# %%
# from sklearn.decomposition import PCA as sklearnPCA
# sklearn_pca = sklearnPCA(n_components=15)
# X_train_pca = sklearn_pca.fit_transform(X_train)
# print(X_train_pca.shape)

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %%
# transform to torch tensor

tensor_x = torch.tensor(X_train, dtype=torch.float).to(device) 
tensor_x2 = torch.tensor(X_test, dtype=torch.float).to(device) 

tensor_y = torch.tensor(Y_train, dtype=torch.float).to(device)
tensor_y2 = torch.tensor(Y_test, dtype=torch.float).to(device)

# %%
type(tensor_x)
# Out:
# torch.Tensor

# %%
trainset = TensorDataset(tensor_x, tensor_y) 
testset = TensorDataset(tensor_x2,tensor_y2)

# %%
def load_data(data_dir=None):
    return trainset, testset

# %%
# %%capture
try:
    import ray
except:
    # !pip install -U ray
    import ray

# %%
from functools import partial
import numpy as np
import os
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
from torchsummary import summary

from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler

# %%
class Net(nn.Module):
    def __init__(self, config):
        super().__init__()

        self.config = config
        self.hidden_dim1 = int(self.config.get("hidden_dim1", 100))
        self.hidden_dim2 = int(self.config.get("hidden_dim2", 100))
        self.hidden_dim3 = int(self.config.get("hidden_dim3", 100))

        self.act1 = self.config.get("act1", "relu") 
        self.act2 = self.config.get("act2", "relu") 
        self.act3 = self.config.get("act3", "relu")

        self.linear1 = nn.Linear(200, self.hidden_dim1)
        self.linear2 = nn.Linear(self.hidden_dim1, self.hidden_dim2)
        self.linear3 = nn.Linear(self.hidden_dim2, self.hidden_dim3)
        self.linear4 = nn.Linear(self.hidden_dim3, 1)
    
    @staticmethod
    def activation_func(act_str):
        if act_str=="tanh":
            return eval("torch."+act_str)
        elif act_str=="selu" or act_str=="relu":   
            return eval("torch.nn.functional."+act_str)

    def forward(self, x):
        output = self.linear1(x)
        output = self.activation_func(self.act1)(output)
        output = self.linear2(output)
        output = self.activation_func(self.act2)(output)
        output = self.linear3(output)
        output = self.activation_func(self.act3)(output)
        output = self.linear4(output)        
        return output

# %%
model = Net({})

# %%
from prettytable import PrettyTable

def count_parameters(model):
    table = PrettyTable(["Modules", "Parameters"])
    total_params = 0
    for name, parameter in model.named_parameters():
        if not parameter.requires_grad: continue
        param = parameter.numel()
        table.add_row([name, param])
        total_params+=param
    print(table)
    print(f"Total Trainable Params: {total_params}")
    return total_params

# %%
#summary(model, (1,tensor_x.shape[1]))

count_parameters(model)
# Out:
# +----------------+------------+
# |    Modules     | Parameters |
# +----------------+------------+
# | linear1.weight |   20000    |
# |  linear1.bias  |    100     |
# | linear2.weight |   10000    |
# |  linear2.bias  |    100     |
# | linear3.weight |   10000    |
# |  linear3.bias  |    100     |
# | linear4.weight |    100     |
# |  linear4.bias  |     1      |
# +----------------+------------+
# Total Trainable Params: 40401
# 40401

# %%
def trainable_func(config, checkpoint_dir=None, data_dir=None, epochs=10):

    net = Net(config)

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    '''
    Define a loss function
    '''
    ## Classification
    # criterion = nn.CrossEntropyLoss()

    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Define an optimizer 
    optimizer = optim.Adam(net.parameters(), lr=config.get("lr",0.0003))

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(
            os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    # Load data
    trainset, testset = load_data(data_dir)

    # Split the dataset into training and validation sets
    train_size = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(trainset, [train_size, len(trainset) - train_size])

    # Define data loaders (which combines a dataset and a sampler, and provides an iterable over the given dataset)
    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config.get("batch_size",32)),
        shuffle=True,
        num_workers=2)

    for epoch in range(epochs):  # loop over the dataset multiple times
        epoch_train_loss = 0.0
        # epoch_steps = 0
        net.train() # Prepare model for training
        for i, data in enumerate(trainloader):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            '''
            Compute train loss without scaling to print
            ''' 
            # outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            # labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device)  
            # loss_train = criterion(outputs, labels) 
            # epoch_train_loss += loss_train.detach().item()
        # print("[%d] loss: %.3f" % (epoch + 1, epoch_train_loss / len(train_subset)))

        # Validation loss
        val_loss = 0.0
        net.eval() # Prepare model for evaluation
        for i, data in enumerate(valloader):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)

                # Inverse transform of the labels' scaler
                outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
                labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(epoch = epoch, loss=(val_loss / len(val_subset)))
    print("Finished Training")

# %%
def test_score(config, net, device="cpu"):
    trainset, testset = load_data()

    testloader = torch.utils.data.DataLoader(
        testset, batch_size=int(config.get("batch_size",32)), shuffle=False, num_workers=2)
    
    ## Regression
    criterion = nn.MSELoss(reduction='sum')

    # Test loss
    test_loss = 0.0
    net.eval() # Prepare model for evaluation
    for i, data in enumerate(testloader):
        with torch.no_grad():
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = net(inputs)

            # Inverse transform of the labels' scaler
            outputs = torch.tensor(scaler_labels.inverse_transform(outputs.detach().cpu())).to(device)    
            labels = torch.tensor(scaler_labels.inverse_transform(labels.cpu())).to(device) 

            loss = criterion(outputs, labels)
            test_loss += loss.cpu().numpy()

    return test_loss / len(testset)

# %%
ray.init() # Here we use ray.init() to evaluate available_resources for Ray
print(ray.available_resources())
ray.shutdown()  # Restart Ray defensively in case the ray connection is lost. 

# Start Ray runtime with specific resources (not nessesarily all resources)
# You can change this values based on your machine resources)
ray.init(num_cpus=2, num_gpus=0) 

"""Check Ray Tune is working properly (for trainable class)"""
# from ray.tune.utils import validate_save_restore
# validate_save_restore(Trainable)
# validate_save_restore(Trainable, use_object_store=True)
# print("Success!")
""""""
# Out:
# {'node:172.28.0.2': 1.0, 'memory': 7927549134.0, 'object_store_memory': 3963774566.0, 'CPU': 2.0}
# ''

# %%
# %%capture
try:
    import optuna
except:
    # %pip install optuna
    import optuna

# %%
def main(num_samples=10, max_num_epochs=10, gpus_per_trial=2):

    # define data directory here if you want to load data from files
    data_dir = os.path.abspath("./data")
    load_data(data_dir)

    # define the search space of hyperparameters
    config = {
        "act1 ": tune.choice(["relu","tanh","selu"]),
        "act2" : tune.choice(["relu","tanh","selu"]),
        "act3" : tune.choice(["relu","tanh","selu"]),
        "lr": tune.quniform(0.0005, 0.001, 0.0001),
        "batch_size": tune.choice([8, 16, 32]),
        "hidden_dim1" : tune.quniform(50, 200, 10),
        "hidden_dim2" : tune.quniform(50, 200, 10),
        "hidden_dim3" : tune.quniform(50, 200, 10),
    }

    # Optuna search algorithm
    from ray.tune.suggest.optuna import OptunaSearch 
    from ray.tune.suggest import ConcurrencyLimiter
    search_alg = OptunaSearch(
        metric="loss", #or accuracy, etc.
        mode="min", #or max
        # seed = 42,
        # points_to_evaluate=[
        # {'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0}
        # ],
        )
    search_alg = ConcurrencyLimiter(search_alg, max_concurrent=10)

    scheduler = ASHAScheduler(
        metric ="loss",
        mode="min",
        max_t=max_num_epochs,
        reduction_factor=2, 
        grace_period=4,
        brackets=5
        )
    
    reporter = CLIReporter(
        # parameter_columns=["l1", "l2", "lr", "batch_size"],
        metric_columns=["loss", "training_iteration"]
        )
    
    # wrap data loading and training for tuning using `partial` 
    # (note that there exist other methods for this purpose)
    result = tune.run(
        partial(trainable_func, data_dir=data_dir, epochs=max_num_epochs),
        scheduler=scheduler,
        search_alg=search_alg,
        num_samples=num_samples,
        config=config,
        verbose=2,
        checkpoint_score_attr="loss",
        checkpoint_freq=0,
        keep_checkpoints_num=1,
        # checkpoint_at_end=True,
        # reuse_actors=reuse_actors_status,
        progress_reporter=reporter,
        resources_per_trial={"cpu": 0.5, "gpu": gpus_per_trial},
        stop={"training_iteration": max_num_epochs},                
        )

    best_trial = result.get_best_trial("loss", "min", "last")
    print("Best trial config: {}".format(best_trial.config))
    print("Best trial final validation score: {}".format(
        best_trial.last_result["loss"]))

    best_trained_model = Net(best_trial.config)
    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if gpus_per_trial > 1:
            best_trained_model = nn.DataParallel(best_trained_model)
    best_trained_model.to(device)

    best_checkpoint_dir = best_trial.checkpoint.value
    model_state, optimizer_state = torch.load(os.path.join(
        best_checkpoint_dir, "checkpoint"))
    best_trained_model.load_state_dict(model_state)

    test_score_value = test_score(best_trial.config, best_trained_model, device)
    print("Best trial test set score: {}".format(test_score_value))


if __name__ == "__main__":
    # You can change the number of GPUs per trial here:
    main(num_samples=50, max_num_epochs=50, gpus_per_trial=0)
# Out:
# 2022-07-15 12:41:14,297	INFO logger.py:630 -- pip install "ray[tune]" to see TensorBoard files.
# 2022-07-15 12:41:14,300	WARNING callback.py:106 -- The TensorboardX logger cannot be instantiated because either TensorboardX or one of it's dependencies is not installed. Please make sure you have the latest version of TensorboardX installed: `pip install -U tensorboardx`
# == Status ==
# Current time: 2022-07-15 12:41:14 (running for 00:00:00.61)
# Memory usage on this node: 1.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 0.5/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 1/50 (1 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------|
# | trainable_func_69d3cfe2 | RUNNING  | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
#
#
# == Status ==
# Current time: 2022-07-15 12:41:20 (running for 00:00:06.14)
# Memory usage on this node: 1.5/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 2/50 (2 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------|
# | trainable_func_69d3cfe2 | RUNNING  | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 |
# | trainable_func_6d6e05e6 | RUNNING  | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+
#
#
# Trial trainable_func_69d3cfe2 reported epoch=0,loss=1.4103708063695366,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# == Status ==
# Current time: 2022-07-15 12:41:27 (running for 00:00:12.95)
# Memory usage on this node: 1.8/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 1.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 3/50 (1 PENDING, 2 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |    loss |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING  | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 1.41037 |                    1 |
# | trainable_func_6d6e05e6 | RUNNING  | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 |         |                      |
# | trainable_func_717d39a4 | PENDING  |                | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 |         |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+---------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=0,loss=2.3777573275318833,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=3,loss=0.8455525732456874,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# == Status ==
# Current time: 2022-07-15 12:41:32 (running for 00:00:18.15)
# Memory usage on this node: 1.9/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.6840355622458172
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING  | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.845553 |                    4 |
# | trainable_func_6d6e05e6 | RUNNING  | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.684036 |                    4 |
# | trainable_func_717d39a4 | RUNNING  | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 |          |                      |
# | trainable_func_73653aa0 | RUNNING  | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 |          |                      |
# | trainable_func_737b2b26 | PENDING  |                | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# == Status ==
# Current time: 2022-07-15 12:41:40 (running for 00:00:26.66)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None | Iter 4.000: -0.6840355622458172
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING  | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.845553 |                    4 |
# | trainable_func_6d6e05e6 | RUNNING  | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.684036 |                    4 |
# | trainable_func_717d39a4 | RUNNING  | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 |          |                      |
# | trainable_func_73653aa0 | RUNNING  | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 |          |                      |
# | trainable_func_737b2b26 | PENDING  |                | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_717d39a4 reported epoch=0,loss=1.4318722729601088,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_6d6e05e6 reported epoch=4,loss=0.6018465481831183,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_73653aa0 reported epoch=0,loss=1.12972802627298,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_69d3cfe2 reported epoch=4,loss=0.7121921875447937,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_717d39a4 reported epoch=5,loss=0.5045265733494024,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-15 12:41:46 (running for 00:00:32.02)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4941496303292908 | Iter 4.000: -0.6840355622458172
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: None
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 5/50 (1 PENDING, 4 RUNNING)
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status   | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING  | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.704381 |                    6 |
# | trainable_func_6d6e05e6 | RUNNING  | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.488647 |                    9 |
# | trainable_func_717d39a4 | RUNNING  | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.504527 |                    6 |
# | trainable_func_73653aa0 | RUNNING  | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.904383 |                    2 |
# | trainable_func_737b2b26 | PENDING  |                | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  |          |                      |
# +-------------------------+----------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=9,loss=0.5330903323297096,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_73653aa0 reported epoch=3,loss=0.7536569675740762,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'tanh', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 8, 'hidden_dim1': 160.0, 'hidden_dim2': 100.0, 'hidden_dim3': 160.0}. This trial completed.
# Trial trainable_func_69d3cfe2 reported epoch=7,loss=0.6887395102545166,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_737b2b26 reported epoch=0,loss=7.6697626895127575,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 130.0, 'hidden_dim3': 70.0}.
# Trial trainable_func_737b2b26 reported epoch=3,loss=1.274727320642874,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'relu', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 90.0, 'hidden_dim2': 130.0, 'hidden_dim3': 70.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 12:41:51 (running for 00:00:37.03)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.4941496303292908 | Iter 4.000: -0.7536569675740762
# Bracket: Iter 32.000: None | Iter 16.000: None | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 7/50 (1 PENDING, 4 RUNNING, 2 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.730641 |                    9 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.504145 |                   14 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.335067 |                   11 |
# | trainable_func_7debd88a | RUNNING    | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 |          |                      |
# | trainable_func_7f6ebb0a | PENDING    |                | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=14,loss=0.43214977524481374,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_7debd88a reported epoch=0,loss=1.865225388652417,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 100.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_717d39a4 reported epoch=11,loss=0.5190173281177617,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=10,loss=0.7585719220580944,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# == Status ==
# Current time: 2022-07-15 12:41:56 (running for 00:00:42.19)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: None | Iter 16.000: -0.45410994567759705 | Iter 8.000: -0.4941496303292908 | Iter 4.000: -0.7188462649099467
# Bracket: Iter 32.000: None | Iter 16.000: -0.4179263340843246 | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 7/50 (1 PENDING, 4 RUNNING, 2 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.676349 |                   12 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.452028 |                   19 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.417926 |                   16 |
# | trainable_func_7debd88a | RUNNING    | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.521837 |                    4 |
# | trainable_func_7f6ebb0a | PENDING    |                | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=19,loss=0.6401334707501216,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_7debd88a reported epoch=4,loss=0.46352552713485584,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 100.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_717d39a4 reported epoch=17,loss=0.39078632063200286,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=13,loss=0.8080690100664454,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_6d6e05e6 reported epoch=24,loss=0.49919005903504815,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-15 12:42:02 (running for 00:00:47.86)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: None | Iter 16.000: -0.45410994567759705 | Iter 8.000: -0.4941496303292908 | Iter 4.000: -0.7188462649099467
# Bracket: Iter 32.000: None | Iter 16.000: -0.4179263340843246 | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: None
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 7/50 (1 PENDING, 4 RUNNING, 2 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.709302 |                   15 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.49919  |                   25 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.399129 |                   21 |
# | trainable_func_7debd88a | RUNNING    | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.49767  |                    7 |
# | trainable_func_7f6ebb0a | PENDING    |                | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_7debd88a reported epoch=8,loss=0.45854105008715795,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 100.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_69d3cfe2 reported epoch=16,loss=0.6857656930062832,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_717d39a4 reported epoch=23,loss=0.37664438024889885,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# == Status ==
# Current time: 2022-07-15 12:42:07 (running for 00:00:52.97)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: None | Iter 16.000: -0.45410994567759705 | Iter 8.000: -0.4732053685530154 | Iter 4.000: -0.7188462649099467
# Bracket: Iter 32.000: None | Iter 16.000: -0.4179263340843246 | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: -0.5795241181339722
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 7/50 (1 PENDING, 4 RUNNING, 2 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.642728 |                   19 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.488146 |                   29 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.417281 |                   26 |
# | trainable_func_7debd88a | RUNNING    | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.467443 |                   11 |
# | trainable_func_7f6ebb0a | PENDING    |                | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=29,loss=0.4940908355943999,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=19,loss=0.725918617869717,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_717d39a4 reported epoch=28,loss=0.36673214648485103,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_7debd88a reported epoch=12,loss=0.5064328728837817,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 100.0, 'hidden_dim3': 60.0}.
# == Status ==
# Current time: 2022-07-15 12:42:12 (running for 00:00:58.23)
# Memory usage on this node: 2.2/12.7 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 32.000: -0.49725374757082796 | Iter 16.000: -0.45410994567759705 | Iter 8.000: -0.4732053685530154 | Iter 4.000: -0.7188462649099467
# Bracket: Iter 32.000: -0.43927722417986 | Iter 16.000: -0.4179263340843246 | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: -0.5795241181339722
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 7/50 (1 PENDING, 4 RUNNING, 2 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.782284 |                   21 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.49663  |                   34 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.439277 |                   32 |
# | trainable_func_7debd88a | RUNNING    | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.462828 |                   14 |
# | trainable_func_7f6ebb0a | PENDING    |                | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=34,loss=0.49223851474090274,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=22,loss=0.5862679379665965,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_7debd88a reported epoch=15,loss=0.4746116215103047,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 8, 'hidden_dim1': 70.0, 'hidden_dim2': 100.0, 'hidden_dim3': 60.0}. This trial completed.
# Trial trainable_func_717d39a4 reported epoch=33,loss=0.5124209286767349,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_7f6ebb0a reported epoch=0,loss=1.242605579369152,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 110.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-15 12:42:17 (running for 00:01:03.39)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 32.000: -0.49725374757082796 | Iter 16.000: -0.4643607835939509 | Iter 8.000: -0.4732053685530154 | Iter 4.000: -0.7188462649099467
# Bracket: Iter 32.000: -0.43927722417986 | Iter 16.000: -0.4179263340843246 | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: -0.5795241181339722
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.636237 |                   24 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.487589 |                   38 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.427383 |                   35 |
# | trainable_func_7f6ebb0a | RUNNING    | 172.28.0.2:999 | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 | 1.24261  |                    1 |
# | trainable_func_8d9943bc | PENDING    |                | relu    | selu   | tanh   |           32 |            60 |           130 |            60 | 0.001  |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# | trainable_func_7debd88a | TERMINATED | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.474612 |                   16 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=38,loss=0.48807258766273603,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=24,loss=0.6102813362149174,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_717d39a4 reported epoch=37,loss=0.40122931345435264,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_7f6ebb0a reported epoch=3,loss=0.6459989624260818,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 110.0, 'hidden_dim3': 90.0}.
# == Status ==
# Current time: 2022-07-15 12:42:23 (running for 00:01:08.92)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=3
# Bracket: Iter 32.000: -0.49725374757082796 | Iter 16.000: -0.4643607835939509 | Iter 8.000: -0.4732053685530154 | Iter 4.000: -0.6840355622458172
# Bracket: Iter 32.000: -0.43927722417986 | Iter 16.000: -0.4179263340843246 | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: -0.5795241181339722
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.593877 |                   27 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.491231 |                   42 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.365225 |                   40 |
# | trainable_func_7f6ebb0a | RUNNING    | 172.28.0.2:999 | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 | 0.645999 |                    4 |
# | trainable_func_8d9943bc | PENDING    |                | relu    | selu   | tanh   |           32 |            60 |           130 |            60 | 0.001  |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# | trainable_func_7debd88a | TERMINATED | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.474612 |                   16 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_6d6e05e6 reported epoch=43,loss=0.45481579445016224,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=27,loss=0.6200892725636079,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_717d39a4 reported epoch=42,loss=0.37287164241628185,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_7f6ebb0a reported epoch=7,loss=0.497884524358407,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 50.0, 'hidden_dim2': 110.0, 'hidden_dim3': 90.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 12:42:28 (running for 00:01:13.95)
# Memory usage on this node: 2.3/12.7 GiB
# Using AsyncHyperBand: num_stopped=4
# Bracket: Iter 32.000: -0.49725374757082796 | Iter 16.000: -0.4643607835939509 | Iter 8.000: -0.4941496303292908 | Iter 4.000: -0.6840355622458172
# Bracket: Iter 32.000: -0.43927722417986 | Iter 16.000: -0.4179263340843246 | Iter 8.000: -0.47329978105247894
# Bracket: Iter 32.000: None | Iter 16.000: -0.5795241181339722
# Bracket: Iter 32.000: None
# Bracket:
# Resources requested: 2.0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 8/50 (1 PENDING, 4 RUNNING, 3 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | RUNNING    | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.614118 |                   29 |
# | trainable_func_6d6e05e6 | RUNNING    | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.57891  |                   47 |
# | trainable_func_717d39a4 | RUNNING    | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.400503 |                   45 |
# | trainable_func_7f6ebb0a | RUNNING    | 172.28.0.2:999 | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 | 0.497885 |                    8 |
# | trainable_func_8d9943bc | PENDING    |                | relu    | selu   | tanh   |           32 |            60 |           130 |            60 | 0.001  |          |                      |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# | trainable_func_7debd88a | TERMINATED | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.474612 |                   16 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Trial trainable_func_8d9943bc reported epoch=0,loss=6.01297862409758,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 60.0}.
# Trial trainable_func_6d6e05e6 reported epoch=48,loss=0.4648025865835802,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_69d3cfe2 reported epoch=30,loss=0.6057681568529848,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'selu', 'lr': 0.0005, 'batch_size': 8, 'hidden_dim1': 110.0, 'hidden_dim2': 150.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_717d39a4 reported epoch=47,loss=0.5659696949396067,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 130.0, 'hidden_dim2': 180.0, 'hidden_dim3': 80.0}.
# Trial trainable_func_6d6e05e6 reported epoch=49,loss=0.5026594202475418,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'relu', 'act3': 'tanh', 'lr': 0.0009, 'batch_size': 16, 'hidden_dim1': 170.0, 'hidden_dim2': 110.0, 'hidden_dim3': 80.0}. This trial completed.
# Trial trainable_func_95e65104 reported epoch=0,loss=2.3745561718893886,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0005, 'batch_size': 16, 'hidden_dim1': 80.0, 'hidden_dim2': 110.0, 'hidden_dim3': 160.0}.
# Trial trainable_func_8d9943bc reported epoch=7,loss=0.5902214150448646,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.001, 'batch_size': 32, 'hidden_dim1': 60.0, 'hidden_dim2': 130.0, 'hidden_dim3': 60.0}. This trial completed.
# == Status ==
# ...
# | trainable_func_0f0d4b50 | TERMINATED | 172.28.0.2:768 | selu    | selu   | tanh   |           16 |           190 |            90 |            90 | 0.0007 | 0.716915 |                    4 |
# | trainable_func_69d3cfe2 | TERMINATED | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.636488 |                   50 |
# | trainable_func_6d6e05e6 | TERMINATED | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.502659 |                   50 |
# | trainable_func_717d39a4 | TERMINATED | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.517884 |                   50 |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# | trainable_func_7debd88a | TERMINATED | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.474612 |                   16 |
# | trainable_func_7f6ebb0a | TERMINATED | 172.28.0.2:999 | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 | 0.497885 |                    8 |
# | trainable_func_8d9943bc | TERMINATED | 172.28.0.2:999 | relu    | selu   | tanh   |           32 |            60 |           130 |            60 | 0.001  | 0.590221 |                    8 |
# | trainable_func_95e65104 | TERMINATED | 172.28.0.2:805 | relu    | selu   | tanh   |           16 |            80 |           110 |           160 | 0.0005 | 0.58111  |                    8 |
# | trainable_func_97a1942c | TERMINATED | 172.28.0.2:999 | tanh    | selu   | selu   |           16 |           140 |           200 |           130 | 0.0006 | 0.641356 |                    8 |
# | trainable_func_98d99628 | TERMINATED | 172.28.0.2:998 | tanh    | tanh   | selu   |           16 |            50 |           110 |           150 | 0.0006 | 0.640623 |                    8 |
# | trainable_func_98ec33dc | TERMINATED | 172.28.0.2:805 | tanh    | tanh   | selu   |           32 |           170 |           160 |           130 | 0.0005 | 0.422797 |                   16 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# ... 30 more trials not shown (30 TERMINATED)
#
#
# Trial trainable_func_13a300ec reported epoch=0,loss=3.691200626708178,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 50.0, 'hidden_dim3': 190.0}.
# Trial trainable_func_0be068fe reported epoch=8,loss=0.6449159148663282,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 150.0}.
# Trial trainable_func_0fab5a8e reported epoch=3,loss=0.7758918430745795,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0007, 'batch_size': 16, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 90.0}. This trial completed.
# Trial trainable_func_fd1e42aa reported epoch=49,loss=0.6182585410748999,should_checkpoint=True with parameters={'act1 ': 'selu', 'act2': 'selu', 'act3': 'relu', 'lr': 0.0009, 'batch_size': 32, 'hidden_dim1': 170.0, 'hidden_dim2': 170.0, 'hidden_dim3': 170.0}. This trial completed.
# Trial trainable_func_13a300ec reported epoch=3,loss=0.740501637279684,should_checkpoint=True with parameters={'act1 ': 'relu', 'act2': 'tanh', 'act3': 'selu', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 90.0, 'hidden_dim2': 50.0, 'hidden_dim3': 190.0}. This trial completed.
# 2022-07-15 12:46:08,052	INFO tune.py:748 -- Total run time: 293.81 seconds (293.59 seconds for the tuning loop).
# Trial trainable_func_0be068fe reported epoch=15,loss=0.504721802114429,should_checkpoint=True with parameters={'act1 ': 'tanh', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0006000000000000001, 'batch_size': 16, 'hidden_dim1': 190.0, 'hidden_dim2': 90.0, 'hidden_dim3': 150.0}. This trial completed.
# == Status ==
# Current time: 2022-07-15 12:46:07 (running for 00:04:53.63)
# Memory usage on this node: 1.4/12.7 GiB
# Using AsyncHyperBand: num_stopped=41
# Bracket: Iter 32.000: -0.41420735144738435 | Iter 16.000: -0.4574136736728383 | Iter 8.000: -0.5080750587490477 | Iter 4.000: -0.6881438422557586
# Bracket: Iter 32.000: -0.4416708574340909 | Iter 16.000: -0.4227970181389465 | Iter 8.000: -0.572843728663069
# Bracket: Iter 32.000: -0.5562513725477934 | Iter 16.000: -0.5744470437562136
# Bracket: Iter 32.000: -0.44286724614855555
# Bracket:
# Resources requested: 0/2 CPUs, 0/0 GPUs, 0.0/7.38 GiB heap, 0.0/3.69 GiB objects
# Result logdir: /root/ray_results/trainable_func_2022-07-15_12-41-14
# Number of trials: 50/50 (50 TERMINATED)
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
# | Trial name              | status     | loc            | act1    | act2   | act3   |   batch_size |   hidden_dim1 |   hidden_dim2 |   hidden_dim3 |     lr |     loss |   training_iteration |
# |-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------|
# | trainable_func_69d3cfe2 | TERMINATED | 172.28.0.2:768 | tanh    | relu   | selu   |            8 |           110 |           150 |           160 | 0.0005 | 0.636488 |                   50 |
# | trainable_func_6d6e05e6 | TERMINATED | 172.28.0.2:805 | tanh    | relu   | tanh   |           16 |           170 |           110 |            80 | 0.0009 | 0.502659 |                   50 |
# | trainable_func_717d39a4 | TERMINATED | 172.28.0.2:998 | relu    | selu   | relu   |           16 |           130 |           180 |            80 | 0.0007 | 0.517884 |                   50 |
# | trainable_func_73653aa0 | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | relu   |            8 |           160 |           100 |           160 | 0.0009 | 0.753657 |                    4 |
# | trainable_func_737b2b26 | TERMINATED | 172.28.0.2:999 | tanh    | relu   | relu   |           32 |            90 |           130 |            70 | 0.001  | 1.27473  |                    4 |
# | trainable_func_7debd88a | TERMINATED | 172.28.0.2:999 | relu    | selu   | selu   |            8 |            70 |           100 |            60 | 0.0006 | 0.474612 |                   16 |
# | trainable_func_7f6ebb0a | TERMINATED | 172.28.0.2:999 | selu    | tanh   | selu   |            8 |            50 |           110 |            90 | 0.0005 | 0.497885 |                    8 |
# | trainable_func_8d9943bc | TERMINATED | 172.28.0.2:999 | relu    | selu   | tanh   |           32 |            60 |           130 |            60 | 0.001  | 0.590221 |                    8 |
# | trainable_func_95e65104 | TERMINATED | 172.28.0.2:805 | relu    | selu   | tanh   |           16 |            80 |           110 |           160 | 0.0005 | 0.58111  |                    8 |
# | trainable_func_97a1942c | TERMINATED | 172.28.0.2:999 | tanh    | selu   | selu   |           16 |           140 |           200 |           130 | 0.0006 | 0.641356 |                    8 |
# | trainable_func_98d99628 | TERMINATED | 172.28.0.2:998 | tanh    | tanh   | selu   |           16 |            50 |           110 |           150 | 0.0006 | 0.640623 |                    8 |
# | trainable_func_98ec33dc | TERMINATED | 172.28.0.2:805 | tanh    | tanh   | selu   |           32 |           170 |           160 |           130 | 0.0005 | 0.422797 |                   16 |
# | trainable_func_9c4b9798 | TERMINATED | 172.28.0.2:998 | tanh    | relu   | relu   |           16 |           180 |           120 |           140 | 0.0007 | 0.722683 |                    4 |
# | trainable_func_9d63d910 | TERMINATED | 172.28.0.2:999 | selu    | selu   | tanh   |           32 |           160 |           140 |           170 | 0.0009 | 0.818189 |                    4 |
# | trainable_func_9dd76cf4 | TERMINATED | 172.28.0.2:999 | selu    | selu   | selu   |            8 |           200 |            70 |           190 | 0.0007 | 0.381627 |                   50 |
# | trainable_func_9f856376 | TERMINATED | 172.28.0.2:998 | selu    | tanh   | selu   |            8 |           100 |            60 |           100 | 0.0005 | 0.641562 |                    8 |
# | trainable_func_a00b577e | TERMINATED | 172.28.0.2:805 | selu    | tanh   | selu   |            8 |           100 |            60 |           100 | 0.0005 | 0.673983 |                    8 |
# | trainable_func_a30e8fae | TERMINATED | 172.28.0.2:998 | relu    | tanh   | selu   |            8 |           100 |            60 |           110 | 0.0006 | 0.439965 |                   16 |
# | trainable_func_a75aa070 | TERMINATED | 172.28.0.2:805 | relu    | tanh   | selu   |           32 |           190 |           160 |           190 | 0.0006 | 1.00888  |                    4 |
# | trainable_func_aa4bd84e | TERMINATED | 172.28.0.2:768 | relu    | tanh   | selu   |           32 |           200 |           160 |           200 | 0.0006 | 0.51004  |                    8 |
# | trainable_func_ab92799c | TERMINATED | 172.28.0.2:805 | relu    | selu   | selu   |           32 |           200 |            80 |           190 | 0.0006 | 0.819475 |                    8 |
# | trainable_func_ac1d5aa8 | TERMINATED | 172.28.0.2:768 | relu    | selu   | selu   |           32 |           200 |            80 |           120 | 0.0007 | 0.923433 |                    4 |
# | trainable_func_af16921a | TERMINATED | 172.28.0.2:805 | relu    | selu   | selu   |            8 |           140 |           180 |           120 | 0.0007 | 0.42283  |                   16 |
# | trainable_func_af7b37c4 | TERMINATED | 172.28.0.2:768 | relu    | selu   | selu   |            8 |           140 |            80 |            50 | 0.0007 | 0.486165 |                   16 |
# | trainable_func_b0b07ff0 | TERMINATED | 172.28.0.2:998 | tanh    | selu   | selu   |            8 |           140 |           180 |           120 | 0.0008 | 0.534025 |                   50 |
# | trainable_func_b65a6d30 | TERMINATED | 172.28.0.2:805 | relu    | tanh   | selu   |            8 |            70 |            50 |           120 | 0.0008 | 0.568069 |                    8 |
# | trainable_func_c0a758de | TERMINATED | 172.28.0.2:768 | relu    | tanh   | selu   |            8 |           140 |           180 |           120 | 0.0008 | 0.718119 |                    4 |
# | trainable_func_c0edd6f6 | TERMINATED | 172.28.0.2:768 | relu    | tanh   | selu   |            8 |           120 |           180 |           120 | 0.0008 | 0.4535   |                   50 |
# | trainable_func_c5171152 | TERMINATED | 172.28.0.2:805 | relu    | tanh   | selu   |            8 |           120 |           180 |           110 | 0.0008 | 0.771338 |                    8 |
# | trainable_func_c7e02180 | TERMINATED | 172.28.0.2:805 | tanh    | tanh   | selu   |            8 |           120 |           180 |           110 | 0.0008 | 0.547882 |                    8 |
# | trainable_func_d03bbbaa | TERMINATED | 172.28.0.2:999 | tanh    | tanh   | selu   |            8 |           160 |           200 |           140 | 0.0007 | 0.695034 |                    8 |
# | trainable_func_d5d6d8ce | TERMINATED | 172.28.0.2:805 | selu    | selu   | selu   |           32 |           160 |           200 |           140 | 0.0008 | 0.444064 |                   32 |
# | trainable_func_d936f986 | TERMINATED | 172.28.0.2:999 | selu    | selu   | tanh   |           32 |           160 |           200 |           180 | 0.0007 | 0.488888 |                   32 |
# | trainable_func_de705bcc | TERMINATED | 172.28.0.2:805 | selu    | selu   | tanh   |           32 |           180 |           160 |           180 | 0.0007 | 0.341691 |                   50 |
# | trainable_func_e66544be | TERMINATED | 172.28.0.2:999 | selu    | relu   | tanh   |           32 |           180 |           150 |           180 | 0.0007 | 0.556251 |                   32 |
# | trainable_func_ec32a440 | TERMINATED | 172.28.0.2:998 | selu    | relu   | selu   |            8 |           180 |           150 |           100 | 0.0005 | 0.528599 |                    8 |
# | trainable_func_eff33928 | TERMINATED | 172.28.0.2:998 | selu    | relu   | selu   |            8 |           180 |           160 |           100 | 0.0005 | 0.688144 |                    4 |
# | trainable_func_f89ced8a | TERMINATED | 172.28.0.2:999 | selu    | relu   | relu   |            8 |           180 |            70 |           130 | 0.0006 | 0.744355 |                    4 |
# | trainable_func_fa0c83ec | TERMINATED | 172.28.0.2:768 | relu    | selu   | relu   |            8 |           110 |            70 |            80 | 0.0006 | 0.508075 |                    8 |
# | trainable_func_fc2d458a | TERMINATED | 172.28.0.2:805 | tanh    | selu   | relu   |            8 |           150 |            70 |           150 | 0.0006 | 0.50597  |                   16 |
# | trainable_func_fcc91b36 | TERMINATED | 172.28.0.2:998 | selu    | selu   | tanh   |           32 |           170 |           160 |           200 | 0.0009 | 0.396267 |                   50 |
# | trainable_func_fd1e42aa | TERMINATED | 172.28.0.2:999 | selu    | selu   | relu   |           32 |           170 |           170 |           170 | 0.0009 | 0.618259 |                   50 |
# | trainable_func_fe505f0a | TERMINATED | 172.28.0.2:768 | selu    | selu   | tanh   |           32 |           170 |           170 |           200 | 0.0009 | 0.758381 |                    4 |
# | trainable_func_04651c1e | TERMINATED | 172.28.0.2:768 | selu    | selu   | tanh   |           32 |           170 |           170 |           170 | 0.0009 | 0.802418 |                    4 |
# | trainable_func_064206d2 | TERMINATED | 172.28.0.2:768 | tanh    | selu   | tanh   |           32 |           150 |           140 |           170 | 0.0007 | 0.642564 |                    8 |
# | trainable_func_0866d38e | TERMINATED | 172.28.0.2:768 | tanh    | selu   | tanh   |           32 |           190 |           140 |           150 | 0.0007 | 0.809421 |                    8 |
# | trainable_func_0be068fe | TERMINATED | 172.28.0.2:805 | tanh    | selu   | tanh   |           16 |           190 |            90 |           150 | 0.0006 | 0.504722 |                   16 |
# | trainable_func_0f0d4b50 | TERMINATED | 172.28.0.2:768 | selu    | selu   | tanh   |           16 |           190 |            90 |            90 | 0.0007 | 0.716915 |                    4 |
# | trainable_func_0fab5a8e | TERMINATED | 172.28.0.2:768 | selu    | tanh   | selu   |           16 |           190 |            90 |            90 | 0.0007 | 0.775892 |                    4 |
# | trainable_func_13a300ec | TERMINATED | 172.28.0.2:998 | relu    | tanh   | selu   |           16 |            90 |            50 |           190 | 0.0006 | 0.740502 |                    4 |
# +-------------------------+------------+----------------+---------+--------+--------+--------------+---------------+---------------+---------------+--------+----------+----------------------+
#
#
# Best trial config: {'act1 ': 'selu', 'act2': 'selu', 'act3': 'tanh', 'lr': 0.0007, 'batch_size': 32, 'hidden_dim1': 180.0, 'hidden_dim2': 160.0, 'hidden_dim3': 180.0}
# Best trial final validation score: 0.3416909833244015
# Best trial test set score: 0.44051749195790385

# %%
# !pip install -U hyperopt
# !pip install hpbandster ConfigSpace
# !pip install optuna
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: hyperopt in /usr/local/lib/python3.7/dist-packages (0.1.2)
# Collecting hyperopt
#   Downloading hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 5.1 MB/s
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.7/dist-packages (from hyperopt) (2.6.3)
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from hyperopt) (0.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.7.3)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.21.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from hyperopt) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from hyperopt) (1.15.0)
# Collecting py4j
#   Downloading py4j-0.10.9.5-py2.py3-none-any.whl (199 kB)
#      |████████████████████████████████| 199 kB 47.0 MB/s
# Installing collected packages: py4j, hyperopt
#   Attempting uninstall: hyperopt
#     Found existing installation: hyperopt 0.1.2
#     Uninstalling hyperopt-0.1.2:
#       Successfully uninstalled hyperopt-0.1.2
# Successfully installed hyperopt-0.2.7 py4j-0.10.9.5
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting hpbandster
#   Downloading hpbandster-0.7.4.tar.gz (51 kB)
#      |████████████████████████████████| 51 kB 91 kB/s
# Collecting ConfigSpace
#   Downloading ConfigSpace-0.5.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.7 MB)
#      |████████████████████████████████| 4.7 MB 9.3 MB/s
# Collecting Pyro4
#   Downloading Pyro4-4.82-py2.py3-none-any.whl (89 kB)
#      |████████████████████████████████| 89 kB 6.3 MB/s
# Collecting serpent
#   Downloading serpent-1.41-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.21.6)
# Requirement already satisfied: statsmodels in /usr/local/lib/python3.7/dist-packages (from hpbandster) (0.10.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from hpbandster) (1.7.3)
# Collecting netifaces
#   Downloading netifaces-0.11.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (32 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (0.29.30)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from ConfigSpace) (3.0.9)
# Requirement already satisfied: pandas>=0.19 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (1.3.5)
# Requirement already satisfied: patsy>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from statsmodels->hpbandster) (0.5.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.19->statsmodels->hpbandster) (2.8.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from patsy>=0.4.0->statsmodels->hpbandster) (1.15.0)
# Building wheels for collected packages: hpbandster
#   Building wheel for hpbandster (setup.py) ... done
#   Created wheel for hpbandster: filename=hpbandster-0.7.4-py3-none-any.whl size=80006 sha256=a25309cb2cee199ae7a20db2ae57c5cf6d7f22688aed770fbdc874812d0c6aee
#   Stored in directory: /root/.cache/pip/wheels/d9/88/fc/61ab6b9f386a386839668631c39a6dc3c2fb0ec7000d552faa
# Successfully built hpbandster
# Installing collected packages: serpent, Pyro4, netifaces, ConfigSpace, hpbandster
# Successfully installed ConfigSpace-0.5.0 Pyro4-4.82 hpbandster-0.7.4 netifaces-0.11.0 serpent-1.41
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: optuna in /usr/local/lib/python3.7/dist-packages (2.10.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from optuna) (1.21.6)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.7/dist-packages (from optuna) (6.6.0)
# Requirement already satisfied: alembic in /usr/local/lib/python3.7/dist-packages (from optuna) (1.8.1)
# Requirement already satisfied: cliff in /usr/local/lib/python3.7/dist-packages (from optuna) (3.10.1)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from optuna) (3.13)
# Requirement already satisfied: scipy!=1.4.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.7.3)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (1.4.39)
# Requirement already satisfied: cmaes>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from optuna) (0.8.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from optuna) (21.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from optuna) (4.64.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->optuna) (3.0.9)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (1.1.2)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from sqlalchemy>=1.1.0->optuna) (4.12.0)
# Requirement already satisfied: Mako in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (1.2.1)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from alembic->optuna) (5.8.0)
# Requirement already satisfied: autopage>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (0.5.1)
# Requirement already satisfied: stevedore>=2.0.1 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (5.9.0)
# Requirement already satisfied: PrettyTable>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (3.3.0)
# Requirement already satisfied: cmd2>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from cliff->optuna) (2.4.2)
# Requirement already satisfied: attrs>=16.3.0 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (21.4.0)
# Requirement already satisfied: wcwidth>=0.1.7 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (0.2.5)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (4.1.1)
# Requirement already satisfied: pyperclip>=1.6 in /usr/local/lib/python3.7/dist-packages (from cmd2>=1.0.0->cliff->optuna) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->sqlalchemy>=1.1.0->optuna) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from Mako->alembic->optuna) (2.0.1)

# %%
from ray.tune.suggest.hyperopt import HyperOptSearch
from ray.tune.suggest.optuna import OptunaSearch  
from ray.tune.suggest.dragonfly import DragonflySearch
from ray.tune.suggest.bayesopt import BayesOptSearch
from ray.tune.schedulers.hb_bohb import HyperBandForBOHB
from ray.tune.schedulers import AsyncHyperBandScheduler
from ray.tune.schedulers import MedianStoppingRule
from ray.tune.schedulers import PopulationBasedTraining
from ray.tune.suggest.bohb import TuneBOHB
from ray.tune.suggest.basic_variant import BasicVariantGenerator
from ray.tune.suggest import ConcurrencyLimiter
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
training_iteration = 50 #max_num_epochs

## ASHA
scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration",
    max_t=training_iteration,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    reduction_factor=2, 
    grace_period=4,
    brackets=5,
    )

## BOHB
scheduler = HyperBandForBOHB(
    time_attr="training_iteration",
    max_t=training_iteration, 
    reduction_factor=8, 
    stop_last_trials=True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## Median
scheduler = MedianStoppingRule(
    time_attr="training_iteration",
    grace_period=10,
    min_samples_required=10,
    hard_stop = True,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    )

## PBT
scheduler = PopulationBasedTraining(
    time_attr="training_iteration",
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    perturbation_interval=10,  # every 10 `time_attr` units
                            # (training_iterations in this case)
    # hyperparam_mutations={
    #     "lr": [8e-3, 7e-3, 6e-3, 5e-3, 4e-3],
    #     "dropout": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout1": tune.quniform(0.0, 0.4, 0.05),
    #     "dropout2": tune.quniform(0.0, 0.4, 0.05),
    #     "max_norm_val":tune.choice([2.5, 3, 3.5, 4]),
    #     }
    )

# %%
# !pip install Cython
# !pip install ConfigSpace

# %%
# !pip install hpbandster ConfigSpace

# %%
# !pip install dragonfly-opt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting dragonfly-opt
#   Downloading dragonfly-opt-0.1.6.tar.gz (252 kB)
#      |████████████████████████████████| 252 kB 5.2 MB/s
# Requirement already satisfied: future in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (0.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.7.3)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from dragonfly-opt) (1.15.0)
# Building wheels for collected packages: dragonfly-opt
#   Building wheel for dragonfly-opt (setup.py) ... done
#   Created wheel for dragonfly-opt: filename=dragonfly_opt-0.1.6-cp37-cp37m-linux_x86_64.whl size=411405 sha256=cf6c8a32270d780608a48f0b1aacdd056576be13ef28fd458454c48a62b515c0
#   Stored in directory: /root/.cache/pip/wheels/bb/79/94/461f622bdd697be30dfe11c2590b574deee78320aa6f5cc2ba
# Successfully built dragonfly-opt
# Installing collected packages: dragonfly-opt
# Successfully installed dragonfly-opt-0.1.6

# %%
from ray.tune.suggest.dragonfly import DragonflySearch

# %%
import dragonfly

# %%
## BOHB
search_alg = TuneBOHB(
    # space=config_space,  # If you want to set the space manually
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # ],
    )

## Hyperopt
search_alg = HyperOptSearch(
    # space=config,
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    n_initial_points=60,
    # gamma = 0.1,
    # random_state_seed=42,
    # points_to_evaluate=[{"max_norm_val": 2.5, 'GNN_Layers': 3, 'dropout': 0.25, 'dropout1': 0.35, 'dropout2': 0.15, 'lr': 0.001, 'hidden_size': 80, 'readout1_out': 150, 'readout2_out': 100, 'batch_size': 64}],
    )

## Optuna
search_alg = OptunaSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    # seed = 42,
    # points_to_evaluate=[
    # {'dropout': 0.2, 'dropout1': 0.1, 'dropout2': 0.25, 'lr': 0.0005, 'hidden_size': 150.0, 'readout1_out': 200.0, 'readout2_out': 180.0, 'max_norm_val': 2.5}
    # ],
    )

## Dragonfly
search_alg = DragonflySearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    optimizer="bandit", #[random, bandit, genetic]
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    # domain=euclidean, #[cartesian, euclidean]
    )

## Bayesopt
search_alg = BayesOptSearch(
    metric="loss", #or accuracy, etc.
    mode="min", #or max
    random_search_steps = 60, 
    # points_to_evaluate=[
    # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
    # ],
    )
# Out:
# ERROR:root:An unexpected error occurred while tokenizing input
# The following traceback may be corrupted or invalid
# The error message is: ('EOF in multi-line string', (226, 73))
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-51-b5459d103f61> in <module>()
#      34     metric="loss", #or accuracy, etc.
#      35     mode="min", #or max
# ---> 36     optimizer="bandit", #[random, bandit, genetic]
#      37     # points_to_evaluate=[
#      38     # {'max_norm_val': 2.5, 'dropout': 0.3, 'dropout1': 0.1, 'dropout2': 0.0, 'lr': 0.0008, 'hidden_size': 90, 'readout1_out': 150, 'readout2_out': 140}
#
# /usr/local/lib/python3.7/dist-packages/ray/tune/suggest/dragonfly.py in __init__(self, optimizer, domain, space, metric, mode, points_to_evaluate, evaluated_rewards, random_state_seed, **kwargs)
#     164         ), """dragonfly must be installed!
#     165             You can install Dragonfly with the command:
# --> 166             `pip install dragonfly-opt`."""
#     167         if mode:
#     168             assert mode in ["min", "max"], "`mode` must be 'min' or 'max'."
#
# AssertionError: dragonfly must be installed!
#             You can install Dragonfly with the command:
#             `pip install dragonfly-opt`.
